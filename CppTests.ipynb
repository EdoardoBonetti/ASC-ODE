# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
# !/home/edo/ASC-ODE/build/test_alpha > output_alpha.txt


alpha = pd.read_csv("output_alpha.txt", sep=" ", names=["t", "x", "y", "z"])
display(alpha)

plt.plot(alpha["t"], alpha["x"])
plt.plot(alpha["t"], alpha["y"])
plt.plot(alpha["t"], alpha["z"])
# Out:
#               t         x         y         z
# 0      0.314159  0.998785 -0.049288 -0.012330
# 1      0.628319  0.985348 -0.170558 -0.119423
# 2      0.942478  0.931490 -0.363768 -0.373204
# 3      1.256640  0.800345 -0.599540 -0.722567
# 4      1.570800  0.571271 -0.820762 -1.051510
# ..          ...       ...       ...       ...
# 995  312.903000 -0.014638 -0.999893 -0.499991
# 996  313.217000 -0.016488 -0.999864 -0.499927
# 997  313.531000 -0.016834 -0.999858 -0.499903
# 998  313.845000 -0.015657 -0.999877 -0.499926
# 999  314.159000 -0.013072 -0.999915 -0.499987
#
# [1000 rows x 4 columns]

# %%
# !/home/edo/ASC-ODE/build/test_newmark > output_newmark.txt


newmark = pd.read_csv("output_newmark.txt", sep=" ", names=["t", "x"])
display(newmark)

plt.plot(newmark["t"], newmark["x"])
# Out:
#            t         x
# 0   0.062832  0.998028
# 1   0.125664  0.992120
# 2   0.188496  0.982299
# 3   0.251327  0.968604
# 4   0.314159  0.951088
# ..       ...       ...
# 95  6.031860  0.968088
# 96  6.094690  0.981910
# 97  6.157520  0.991859
# 98  6.220350  0.997896
# 99  6.283190  0.999998
#
# [100 rows x 2 columns]

# %%
# !/home/edo/ASC-ODE/build/test_ode > output_ode.txt

ode = pd.read_csv("output_ode.txt", sep=" ", names=["t", "x", "y"])
display(ode)

plt.plot(ode["x"])
plt.plot( ode["y"])
# Out:
#             t         x         y
# 0.125664  NaN  0.984454 -0.123710
# 0.251327  NaN  0.953846 -0.243574
# 0.376991  NaN  0.908885 -0.357788
# 0.502655  NaN  0.850493 -0.464664
# 0.628319  NaN  0.779788 -0.562655
# ...        ..       ...       ...
# 12.063700 NaN  0.397992  0.252614
# 12.189400 NaN  0.423055  0.199452
# 12.315000 NaN  0.441153  0.144015
# 12.440700 NaN  0.452111  0.087201
# 12.566400 NaN  0.455870  0.029915
#
# [100 rows x 3 columns]
